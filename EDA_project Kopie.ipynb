# %%
import pandas as pd
#from openpyxl import load_workbook
#df = pd.read_excel('data/Muesli Project raw data.xlsx')
#wb = load_workbook(filename = 'Column Info')
xls = pd.ExcelFile('data/Muesli_project_data_mod1.xlsx')
df_colum = pd.read_csv("Muesli Project raw data - Campaign Data.csv")
#df_orders = pd.read_excel(xls, 'Orders')
#df_campaign = pd.read_excel(xls, 'Campaign Data')
#df_process = pd.read_excel(xls, 'Order Process Data')
#df_intern = pd.read_excel(xls, 'InternData Study')

# %%
# irrelevant for our analysis - only describing Dataset
print(df_colum.info())

# %%
#Columns unnamed need to be adressed 
# Column 2 only contains 5010 values, opposed to 9995 values in the other columns
print(df_orders.info())

# %%
df_orders.drop('Unnamed: 2',axis=1, inplace=True)

# %%
#first row is empty, needs to be dropped
#column C, first 2 ines need to be deleted 

df_orders.head(5)

# %%
print(df_campaign.info())

# %%
# check if needed convert data to.datetime ??? maybe info says otherwise
df_campaign.head()
# Out:
#          Order ID Arrival Scan Date   Customer Name
# 0  CA-2019-100041        2019-12-02  Barbara Fisher
# 1  CA-2019-100083        2019-12-09    Carol Darley
# 2  CA-2019-100244        2019-09-30    Greg Maxwell
# 3  CA-2019-100468        2019-12-09     Alyssa Tate
# 4  CA-2019-100510        2019-05-28     Harry Marie

# %%
print(df_process.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5899 entries, 0 to 5898
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Row ID              5899 non-null   int64
#  1   Order ID            5899 non-null   object
#  2   Order Date          5899 non-null   datetime64[ns]
#  3   On Truck Scan Date  5899 non-null   datetime64[ns]
#  4   Ship Mode           5899 non-null   object
# dtypes: datetime64[ns](2), int64(1), object(2)
# memory usage: 230.6+ KB
# None

# %%
df_process.drop('Row ID',axis=1, inplace=True)

# %%
df_process.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5899 entries, 0 to 5898
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order ID            5899 non-null   object
#  1   Order Date          5899 non-null   datetime64[ns]
#  2   On Truck Scan Date  5899 non-null   datetime64[ns]
#  3   Ship Mode           5899 non-null   object
# dtypes: datetime64[ns](2), object(2)
# memory usage: 184.5+ KB

# %%
# check if needed convert data to.datetime ??? maybe info says otherwise
df_process.head()
# Out:
#          Order ID Order Date On Truck Scan Date            Ship Mode
# 0  CA-2019-125206 2019-01-03         2019-01-07              Express
# 1  CA-2019-160304 2019-01-02         2019-01-09  Standard Processing
# 2  CA-2019-160304 2019-01-02         2019-01-09  Standard Processing
# 3  US-2019-116365 2019-01-03         2019-01-09  Standard Processing
# 4  US-2019-116365 2019-01-03         2019-01-09  Standard Processing

# %%
print(df_intern.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order ID            290 non-null    object
#  1   Ready to Ship Date  290 non-null    datetime64[ns]
#  2   Pickup Date         290 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), object(1)
# memory usage: 6.9+ KB
# None

# %%
df_intern.head()
# Out:
#          Order ID Ready to Ship Date Pickup Date
# 0  CA-2019-100244         2019-09-24  2019-09-25
# 1  CA-2019-100244         2019-09-24  2019-09-25
# 2  CA-2019-100244         2019-09-24  2019-09-25
# 3  CA-2019-100244         2019-09-24  2019-09-25
# 4  CA-2019-100244         2019-09-24  2019-09-25

# %%
uni_ord = df_orders['Order ID'].unique()
print(uni_ord)
# Out:
# ['CA-2019-121755' 'CA-2019-118255' 'CA-2019-169194' ... 'CA-2020-107209'
#  'US-2020-152842' 'CA-2019-122581']

# %%
uni_grp = df_orders.groupby('Order ID').count()
print(uni_grp)
# Out:
#                 Index  Order Date  Ship Mode  Customer ID  Customer Name  \
# Order ID
# CA-2017-100006      1           1          1            1              1
# CA-2017-100090      2           2          2            2              2
# CA-2017-100293      1           1          1            1              1
# CA-2017-100328      1           1          1            1              1
# CA-2017-100363      2           2          2            2              2
# ...               ...         ...        ...          ...            ...
# US-2020-168802      1           1          1            1              1
# US-2020-169320      2           2          2            2              2
# US-2020-169488      2           2          2            2              2
# US-2020-169502      2           2          2            2              2
# US-2020-169551      6           6          6            6              6
#
#                 Origin Channel  Country/Region  City  State  Postal Code  \
# Order ID
# CA-2017-100006               1               1     1      1            1
# CA-2017-100090               2               2     2      2            2
# CA-2017-100293               1               1     1      1            1
# CA-2017-100328               1               1     1      1            1
# CA-2017-100363               2               2     2      2            2
# ...                        ...             ...   ...    ...          ...
# US-2020-168802               1               1     1      1            1
# US-2020-169320               2               2     2      2            2
# US-2020-169488               2               2     2      2            2
# US-2020-169502               2               2     2      2            2
# US-2020-169551               6               6     6      6            6
#
#                 Region  Category  Sub-Category  Product ID  Sales  Quantity  \
# Order ID
# CA-2017-100006       1         1             1           1      1         1
# CA-2017-100090       2         2             2           2      2         2
# CA-2017-100293       1         1             1           1      1         1
# CA-2017-100328       1         1             1           1      1         1
# CA-2017-100363       2         2             2           2      2         2
# ...                ...       ...           ...         ...    ...       ...
# US-2020-168802       1         1             1           1      1         1
# US-2020-169320       2         2             2           2      2         2
# US-2020-169488       2         2             2           2      2         2
# US-2020-169502       2         2             2           2      2         2
# US-2020-169551       6         6             6           6      6         6
#
#                 Discount  Profit
# Order ID
# CA-2017-100006         1       1
# CA-2017-100090         2       2
# CA-2017-100293         1       1
# CA-2017-100328         1       1
# CA-2017-100363         2       2
# ...                  ...     ...
# US-2020-168802         1       1
# US-2020-169320         2       2
# US-2020-169488         2       2
# US-2020-169502         2       2
# US-2020-169551         6       6
#
# [5009 rows x 18 columns]

# %%
merge_df = pd.merge(df_orders, df_campaign,  on='Order ID', how='outer')

# %%
supermerge = pd.merge(df_intern, df_process, on ='Order ID', how='outer')
supermerge
# Out:
#             Order ID Ready to Ship Date Pickup Date Order Date  \
# 0     CA-2019-100244         2019-09-24  2019-09-25 2019-09-20
# 1     CA-2019-100244         2019-09-24  2019-09-25 2019-09-20
# 2     CA-2019-100244         2019-09-24  2019-09-25 2019-09-20
# 3     CA-2019-100244         2019-09-24  2019-09-25 2019-09-20
# 4     CA-2019-100244         2019-09-24  2019-09-25 2019-09-20
# ...              ...                ...         ...        ...
# 6229  CA-2020-143259                NaT         NaT 2020-12-30
# 6230  CA-2020-143259                NaT         NaT 2020-12-30
# 6231  CA-2020-115427                NaT         NaT 2020-12-30
# 6232  CA-2020-115427                NaT         NaT 2020-12-30
# 6233  CA-2020-156720                NaT         NaT 2020-12-30
#
#      On Truck Scan Date            Ship Mode
# 0            2019-09-25  Standard Processing
# 1            2019-09-25  Standard Processing
# 2            2019-09-25  Standard Processing
# 3            2019-09-25  Standard Processing
# 4            2019-09-25  Standard Processing
# ...                 ...                  ...
# 6229         2021-01-06  Standard Processing
# 6230         2021-01-06  Standard Processing
# 6231         2021-01-06  Standard Processing
# 6232         2021-01-06  Standard Processing
# 6233         2021-01-06  Standard Processing
#
# [6234 rows x 6 columns]

# %%
ultramerge = pd.merge(merge_df, supermerge, on ='Order ID', how='outer')
ultramerge
# Out:
#        Index        Order ID Order Date_x     Ship Mode_x Customer ID  \
# 0         27  CA-2019-121755   2019-01-16    Second Class    EH-13945
# 1         27  CA-2019-121755   2019-01-16    Second Class    EH-13945
# 2         26  CA-2019-121755   2019-01-16    Second Class    EH-13945
# 3         26  CA-2019-121755   2019-01-16    Second Class    EH-13945
# 4         45  CA-2019-118255   2019-03-11     First Class    ON-18715
# ...      ...             ...          ...             ...         ...
# 23166   9760  CA-2019-146913   2019-10-31  Standard Class    SF-20965
# 23167   9787  US-2017-114377   2017-11-05     First Class    BG-11035
# 23168   9808  CA-2020-107209   2020-07-27    Second Class    JW-15955
# 23169   9830  US-2020-152842   2020-07-16  Standard Class    NF-18385
# 23170   9880  CA-2019-122581   2019-08-21  Standard Class    JK-15370
#
#         Customer Name_x Origin Channel Country/Region           City  \
# 0         Eric Hoffmann          Email  United States    Los Angeles
# 1         Eric Hoffmann          Email  United States    Los Angeles
# 2         Eric Hoffmann          Email  United States    Los Angeles
# 3         Eric Hoffmann          Email  United States    Los Angeles
# 4         Odella Nelson          Sales  United States          Eagan
# ...                 ...            ...            ...            ...
# 23166   Sylvia Foulston          Sales  United States  San Francisco
# 23167    Barry Gonzalez          Email  United States        Hampton
# 23168    Joni Wasserman          Email  United States        Raleigh
# 23169  Natalie Fritzler          Email  United States      Charlotte
# 23170        Jay Kimmel          Email  United States  New York City
#
#                 State  Postal Code   Region                 Category  \
# 0          California      90049.0     West  Special Projects Muesil
# 1          California      90049.0     West  Special Projects Muesil
# 2          California      90049.0     West             Power Muesli
# 3          California      90049.0     West             Power Muesli
# 4           Minnesota      55122.0  Central  Special Projects Muesil
# ...               ...          ...      ...                      ...
# 23166      California      94109.0     West           Toasted Muesli
# 23167        Virginia      23666.0    South           Toasted Muesli
# 23168  North Carolina      27604.0    South           Toasted Muesli
# 23169  North Carolina      28205.0    South           Toasted Muesli
# 23170        New York      10035.0     East           Toasted Muesli
#
#             Sub-Category       Product ID     Sales  Quantity  Discount  \
# 0            Gluten Free  TEC-AC-10003027    90.570         3       0.0
# 1            Gluten Free  TEC-AC-10003027    90.570         3       0.0
# 2      Super Fibre Boost  OFF-BI-10001634    11.648         2       0.2
# 3      Super Fibre Boost  OFF-BI-10001634    11.648         2       0.2
# 4            Gluten Free  TEC-AC-10000171    45.980         2       0.0
# ...                  ...              ...       ...       ...       ...
# 23166          With Nuts  FUR-CH-10001854  1403.920         5       0.2
# 23167          With Nuts  FUR-CH-10004754   149.900         5       0.0
# 23168          With Nuts  FUR-CH-10001146   194.848         4       0.2
# 23169          With Nuts  FUR-CH-10004218   242.352         3       0.2
# 23170          With Nuts  FUR-CH-10002961   573.174         7       0.1
#
#         Profit Arrival Scan Date  Customer Name_y Ready to Ship Date  \
# 0      11.7741               NaT              NaN                NaT
# 1      11.7741               NaT              NaN                NaT
# 2       4.2224               NaT              NaN                NaT
# 3       4.2224               NaT              NaN                NaT
# 4      19.7714               NaT              NaN                NaT
# ...        ...               ...              ...                ...
# 23166  70.1960        2019-11-11  Sylvia Foulston                NaT
# 23167  40.4730               NaT              NaN                NaT
# 23168  12.1780               NaT              NaN                NaT
# 23169  15.1470               NaT              NaN                NaT
# 23170  63.6860               NaT              NaN                NaT
#
#       Pickup Date Order Date_y On Truck Scan Date          Ship Mode_y
# 0             NaT   2019-01-16         2019-01-23  Standard Processing
# 1             NaT   2019-01-16         2019-01-23  Standard Processing
# 2             NaT   2019-01-16         2019-01-23  Standard Processing
# 3             NaT   2019-01-16         2019-01-23  Standard Processing
# 4             NaT   2019-03-11         2019-03-13              Express
# ...           ...          ...                ...                  ...
# 23166         NaT   2019-10-31         2019-11-06  Standard Processing
# 23167         NaT          NaT                NaT                  NaN
# 23168         NaT   2020-07-27         2020-08-05  Standard Processing
# 23169         NaT   2020-07-16         2020-07-24  Standard Processing
# 23170         NaT   2019-08-21         2019-08-28  Standard Processing
#
# [23171 rows x 26 columns]

# %%
ultramerge = ultramerge.replace(" ","_")
ultramerge.drop('Index', axis=1, inplace=True)
ultramerge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23171 entries, 0 to 23170
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order ID            23171 non-null  object
#  1   Order Date_x        23171 non-null  datetime64[ns]
#  2   Ship Mode_x         23171 non-null  object
#  3   Customer ID         23171 non-null  object
#  4   Customer Name_x     23171 non-null  object
#  5   Origin Channel      23171 non-null  object
#  6   Country/Region      23171 non-null  object
#  7   City                23171 non-null  object
#  8   State               23171 non-null  object
#  9   Postal Code         23142 non-null  float64
#  10  Region              23171 non-null  object
#  11  Category            23171 non-null  object
#  12  Sub-Category        23171 non-null  object
#  13  Product ID          23171 non-null  object
#  14  Sales               23171 non-null  float64
#  15  Quantity            23171 non-null  int64
#  16  Discount            23171 non-null  float64
#  17  Profit              23171 non-null  float64
#  18  Arrival Scan Date   2211 non-null   datetime64[ns]
#  19  Customer Name_y     2211 non-null   object
#  20  Ready to Ship Date  2771 non-null   datetime64[ns]
#  21  Pickup Date         2771 non-null   datetime64[ns]
#  22  Order Date_y        19076 non-null  datetime64[ns]
#  23  On Truck Scan Date  19076 non-null  datetime64[ns]
#  24  Ship Mode_y         19076 non-null  object
# dtypes: datetime64[ns](6), float64(4), int64(1), object(14)
# memory usage: 4.6+ MB

# %%
with pd.ExcelWriter("data/ultamerge.xlsx") as writer:
    ultramerge.to_excel(writer)

# %%
# identify duplicates
ultramerge[ultramerge.duplicated(keep=False)].sort_values(by=['Order ID']).head(100)
# Out:
#              Order ID Order Date_x     Ship Mode_x Customer ID  \
# 15202  CA-2019-100041   2019-11-20  Standard Class    BF-10975
# 15200  CA-2019-100041   2019-11-20  Standard Class    BF-10975
# 15201  CA-2019-100041   2019-11-20  Standard Class    BF-10975
# 15208  CA-2019-100041   2019-11-20  Standard Class    BF-10975
# 15207  CA-2019-100041   2019-11-20  Standard Class    BF-10975
# ...               ...          ...             ...         ...
# 14641  CA-2019-100244   2019-09-20  Standard Class    GM-14695
# 14642  CA-2019-100244   2019-09-20  Standard Class    GM-14695
# 14643  CA-2019-100244   2019-09-20  Standard Class    GM-14695
# 14644  CA-2019-100244   2019-09-20  Standard Class    GM-14695
# 14645  CA-2019-100244   2019-09-20  Standard Class    GM-14695
#
#       Customer Name_x Origin Channel Country/Region           City  \
# 15202  Barbara Fisher          Sales  United States       Columbus
# 15200  Barbara Fisher          Sales  United States       Columbus
# 15201  Barbara Fisher          Sales  United States       Columbus
# 15208  Barbara Fisher          Sales  United States       Columbus
# 15207  Barbara Fisher          Sales  United States       Columbus
# ...               ...            ...            ...            ...
# 14641    Greg Maxwell          Sales  United States  San Francisco
# 14642    Greg Maxwell          Sales  United States  San Francisco
# 14643    Greg Maxwell          Sales  United States  San Francisco
# 14644    Greg Maxwell          Sales  United States  San Francisco
# 14645    Greg Maxwell          Sales  United States  San Francisco
#
#             State  Postal Code   Region      Category       Sub-Category  \
# 15202     Indiana      47201.0  Central  Power Muesli      Nuts and more
# 15200     Indiana      47201.0  Central  Power Muesli      Nuts and more
# 15201     Indiana      47201.0  Central  Power Muesli      Nuts and more
# 15208     Indiana      47201.0  Central  Power Muesli  Super Fibre Boost
# 15207     Indiana      47201.0  Central  Power Muesli  Super Fibre Boost
# ...           ...          ...      ...           ...                ...
# 14641  California      94122.0     West  Power Muesli      Nuts and more
# 14642  California      94122.0     West  Power Muesli      Nuts and more
# 14643  California      94122.0     West  Power Muesli      Nuts and more
# 14644  California      94122.0     West  Power Muesli      Nuts and more
# 14645  California      94122.0     West  Power Muesli      Nuts and more
#
#             Product ID  Sales  Quantity  Discount   Profit Arrival Scan Date  \
# 15202  OFF-PA-10001622   9.08         2       0.0   4.0860        2019-12-02
# 15200  OFF-PA-10001622   9.08         2       0.0   4.0860        2019-12-02
# 15201  OFF-PA-10001622   9.08         2       0.0   4.0860        2019-12-02
# 15208  OFF-BI-10000343   4.91         1       0.0   2.3077        2019-12-02
# 15207  OFF-BI-10000343   4.91         1       0.0   2.3077        2019-12-02
# ...                ...    ...       ...       ...      ...               ...
# 14641  OFF-PA-10001471  65.79         9       0.0  30.2634        2019-09-30
# 14642  OFF-PA-10001471  65.79         9       0.0  30.2634        2019-09-30
# 14643  OFF-PA-10001471  65.79         9       0.0  30.2634        2019-09-30
# 14644  OFF-PA-10001471  65.79         9       0.0  30.2634        2019-09-30
# 14645  OFF-PA-10001471  65.79         9       0.0  30.2634        2019-09-30
#
#       Customer Name_y Ready to Ship Date Pickup Date Order Date_y  \
# 15202  Barbara Fisher                NaT         NaT   2019-11-20
# 15200  Barbara Fisher                NaT         NaT   2019-11-20
# 15201  Barbara Fisher                NaT         NaT   2019-11-20
# 15208  Barbara Fisher                NaT         NaT   2019-11-20
# 15207  Barbara Fisher                NaT         NaT   2019-11-20
# ...               ...                ...         ...          ...
# 14641    Greg Maxwell         2019-09-24  2019-09-25   2019-09-20
# 14642    Greg Maxwell         2019-09-24  2019-09-25   2019-09-20
# 14643    Greg Maxwell         2019-09-24  2019-09-25   2019-09-20
# 14644    Greg Maxwell         2019-09-24  2019-09-25   2019-09-20
# 14645    Greg Maxwell         2019-09-24  2019-09-25   2019-09-20
#
#       On Truck Scan Date          Ship Mode_y
# 15202         2019-11-27  Standard Processing
# 15200         2019-11-27  Standard Processing
# 15201         2019-11-27  Standard Processing
# 15208         2019-11-27  Standard Processing
# 15207         2019-11-27  Standard Processing
# ...                  ...                  ...
# 14641         2019-09-25  Standard Processing
# 14642         2019-09-25  Standard Processing
# 14643         2019-09-25  Standard Processing
# 14644         2019-09-25  Standard Processing
# 14645         2019-09-25  Standard Processing
#
# [100 rows x 25 columns]

# %%
ultramerge.drop_duplicates(inplace=True)
ultramerge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9995 entries, 0 to 23170
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order ID            9995 non-null   object
#  1   Order Date_x        9995 non-null   datetime64[ns]
#  2   Ship Mode_x         9995 non-null   object
#  3   Customer ID         9995 non-null   object
#  4   Customer Name_x     9995 non-null   object
#  5   Origin Channel      9995 non-null   object
#  6   Country/Region      9995 non-null   object
#  7   City                9995 non-null   object
#  8   State               9995 non-null   object
#  9   Postal Code         9984 non-null   float64
#  10  Region              9995 non-null   object
#  11  Category            9995 non-null   object
#  12  Sub-Category        9995 non-null   object
#  13  Product ID          9995 non-null   object
#  14  Sales               9995 non-null   float64
#  15  Quantity            9995 non-null   int64
#  16  Discount            9995 non-null   float64
#  17  Profit              9995 non-null   float64
#  18  Arrival Scan Date   668 non-null    datetime64[ns]
#  19  Customer Name_y     668 non-null    object
#  20  Ready to Ship Date  418 non-null    datetime64[ns]
#  21  Pickup Date         418 non-null    datetime64[ns]
#  22  Order Date_y        5901 non-null   datetime64[ns]
#  23  On Truck Scan Date  5901 non-null   datetime64[ns]
#  24  Ship Mode_y         5901 non-null   object
# dtypes: datetime64[ns](6), float64(4), int64(1), object(14)
# memory usage: 2.0+ MB

# %%
# identify duplicates
ultramerge[ultramerge.duplicated(keep=False)].sort_values(by=['Order ID']).head(100)
# Out:
# Empty DataFrame
# Columns: [Order ID, Order Date_x, Ship Mode_x, Customer ID, Customer Name_x, Origin Channel, Country/Region, City, State, Postal Code, Region, Category, Sub-Category, Product ID, Sales, Quantity, Discount, Profit, Arrival Scan Date, Customer Name_y, Ready to Ship Date, Pickup Date, Order Date_y, On Truck Scan Date, Ship Mode_y]
# Index: []

# %%
ultramerge['Order Date_x'].describe()
# Out:
# /var/folders/hk/4wpr3zv9507gpsy2svphsj3w0000gn/T/ipykernel_10005/248598524.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   ultramerge['Order Date_x'].describe()
# count                    9995
# unique                   1236
# top       2019-09-05 00:00:00
# freq                       38
# first     2017-01-03 00:00:00
# last      2020-12-30 00:00:00
# Name: Order Date_x, dtype: object

# %%
ultramerge.head(5)
# Out:
#          Order ID Order Date_x     Ship Mode_x Customer ID Customer Name_x  \
# 0  CA-2019-121755   2019-01-16    Second Class    EH-13945   Eric Hoffmann
# 2  CA-2019-121755   2019-01-16    Second Class    EH-13945   Eric Hoffmann
# 4  CA-2019-118255   2019-03-11     First Class    ON-18715   Odella Nelson
# 6  CA-2019-118255   2019-03-11     First Class    ON-18715   Odella Nelson
# 8  CA-2019-169194   2019-06-20  Standard Class    LH-16900  Lena Hernandez
#
#   Origin Channel Country/Region         City       State  Postal Code  \
# 0          Email  United States  Los Angeles  California      90049.0
# 2          Email  United States  Los Angeles  California      90049.0
# 4          Sales  United States        Eagan   Minnesota      55122.0
# 6          Sales  United States        Eagan   Minnesota      55122.0
# 8          Email  United States        Dover    Delaware      19901.0
#
#     Region                 Category       Sub-Category       Product ID  \
# 0     West  Special Projects Muesil        Gluten Free  TEC-AC-10003027
# 2     West             Power Muesli  Super Fibre Boost  OFF-BI-10001634
# 4  Central  Special Projects Muesil        Gluten Free  TEC-AC-10000171
# 6  Central             Power Muesli  Super Fibre Boost  OFF-BI-10003291
# 8     East  Special Projects Muesil        Gluten Free  TEC-AC-10002167
#
#     Sales  Quantity  Discount   Profit Arrival Scan Date Customer Name_y  \
# 0  90.570         3       0.0  11.7741               NaT             NaN
# 2  11.648         2       0.2   4.2224               NaT             NaN
# 4  45.980         2       0.0  19.7714               NaT             NaN
# 6  17.460         2       0.0   8.2062               NaT             NaN
# 8  45.000         3       0.0   4.9500               NaT             NaN
#
#   Ready to Ship Date Pickup Date Order Date_y On Truck Scan Date  \
# 0                NaT         NaT   2019-01-16         2019-01-23
# 2                NaT         NaT   2019-01-16         2019-01-23
# 4                NaT         NaT   2019-03-11         2019-03-13
# 6                NaT         NaT   2019-03-11         2019-03-13
# 8                NaT         NaT   2019-06-20         2019-06-26
#
#            Ship Mode_y
# 0  Standard Processing
# 2  Standard Processing
# 4              Express
# 6              Express
# 8  Standard Processing

# %%
with pd.ExcelWriter("data/ultamerge2.xlsx") as writer:
    ultramerge.to_excel(writer)

# %%
# change date text string to datetime datatype
ultramerge['Order Date_x'] = pd.to_datetime(ultramerge['Order Date_x'])
#ultramerge['tatzeit_ende_datum'] = pd.to_datetime(ultramerge['tatzeit_ende_datum'])

# %%
pd.set_option('display.max_columns', None)

# %%
ultramerge.head()
# Out:
#          Order ID Order Date_x     Ship Mode_x Customer ID Customer Name_x  \
# 0  CA-2019-121755   2019-01-16    Second Class    EH-13945   Eric Hoffmann
# 2  CA-2019-121755   2019-01-16    Second Class    EH-13945   Eric Hoffmann
# 4  CA-2019-118255   2019-03-11     First Class    ON-18715   Odella Nelson
# 6  CA-2019-118255   2019-03-11     First Class    ON-18715   Odella Nelson
# 8  CA-2019-169194   2019-06-20  Standard Class    LH-16900  Lena Hernandez
#
#   Origin Channel Country/Region         City       State  Postal Code  \
# 0          Email  United States  Los Angeles  California      90049.0
# 2          Email  United States  Los Angeles  California      90049.0
# 4          Sales  United States        Eagan   Minnesota      55122.0
# 6          Sales  United States        Eagan   Minnesota      55122.0
# 8          Email  United States        Dover    Delaware      19901.0
#
#     Region                 Category       Sub-Category       Product ID  \
# 0     West  Special Projects Muesil        Gluten Free  TEC-AC-10003027
# 2     West             Power Muesli  Super Fibre Boost  OFF-BI-10001634
# 4  Central  Special Projects Muesil        Gluten Free  TEC-AC-10000171
# 6  Central             Power Muesli  Super Fibre Boost  OFF-BI-10003291
# 8     East  Special Projects Muesil        Gluten Free  TEC-AC-10002167
#
#     Sales  Quantity  Discount   Profit Arrival Scan Date Customer Name_y  \
# 0  90.570         3       0.0  11.7741               NaT             NaN
# 2  11.648         2       0.2   4.2224               NaT             NaN
# 4  45.980         2       0.0  19.7714               NaT             NaN
# 6  17.460         2       0.0   8.2062               NaT             NaN
# 8  45.000         3       0.0   4.9500               NaT             NaN
#
#   Ready to Ship Date Pickup Date Order Date_y On Truck Scan Date  \
# 0                NaT         NaT   2019-01-16         2019-01-23
# 2                NaT         NaT   2019-01-16         2019-01-23
# 4                NaT         NaT   2019-03-11         2019-03-13
# 6                NaT         NaT   2019-03-11         2019-03-13
# 8                NaT         NaT   2019-06-20         2019-06-26
#
#            Ship Mode_y
# 0  Standard Processing
# 2  Standard Processing
# 4              Express
# 6              Express
# 8  Standard Processing

# %%
#Drop command column by index  --> use later 
#ultramerge.drop(ultramerge.columns[0], axis=1, inplace=True)
#ultramerge.head()

# %%
# unify values for ship mode with ship mode y as reference 
ultramerge['Ship Mode_x'] = ultramerge['Ship Mode_x'].replace(['Second Class'], 'standard_processing')
ultramerge['Ship Mode_x'] = ultramerge['Ship Mode_x'].replace(['Standard Class'], 'standard_processing')
ultramerge['Ship Mode_x'] = ultramerge['Ship Mode_x'].replace(['First Class'], 'express_processing')

# %%
ultramerge.head()
# Out:
#          Order ID Order Date_x          Ship Mode_x Customer ID  \
# 0  CA-2019-121755   2019-01-16  standard_processing    EH-13945
# 2  CA-2019-121755   2019-01-16  standard_processing    EH-13945
# 4  CA-2019-118255   2019-03-11   express_processing    ON-18715
# 6  CA-2019-118255   2019-03-11   express_processing    ON-18715
# 8  CA-2019-169194   2019-06-20  standard_processing    LH-16900
#
#   Customer Name_x Origin Channel Country/Region         City       State  \
# 0   Eric Hoffmann          Email  United States  Los Angeles  California
# 2   Eric Hoffmann          Email  United States  Los Angeles  California
# 4   Odella Nelson          Sales  United States        Eagan   Minnesota
# 6   Odella Nelson          Sales  United States        Eagan   Minnesota
# 8  Lena Hernandez          Email  United States        Dover    Delaware
#
#    Postal Code   Region                 Category       Sub-Category  \
# 0      90049.0     West  Special Projects Muesil        Gluten Free
# 2      90049.0     West             Power Muesli  Super Fibre Boost
# 4      55122.0  Central  Special Projects Muesil        Gluten Free
# 6      55122.0  Central             Power Muesli  Super Fibre Boost
# 8      19901.0     East  Special Projects Muesil        Gluten Free
#
#         Product ID   Sales  Quantity  Discount   Profit Arrival Scan Date  \
# 0  TEC-AC-10003027  90.570         3       0.0  11.7741               NaT
# 2  OFF-BI-10001634  11.648         2       0.2   4.2224               NaT
# 4  TEC-AC-10000171  45.980         2       0.0  19.7714               NaT
# 6  OFF-BI-10003291  17.460         2       0.0   8.2062               NaT
# 8  TEC-AC-10002167  45.000         3       0.0   4.9500               NaT
#
#   Customer Name_y Ready to Ship Date Pickup Date Order Date_y  \
# 0             NaN                NaT         NaT   2019-01-16
# 2             NaN                NaT         NaT   2019-01-16
# 4             NaN                NaT         NaT   2019-03-11
# 6             NaN                NaT         NaT   2019-03-11
# 8             NaN                NaT         NaT   2019-06-20
#
#   On Truck Scan Date          Ship Mode_y
# 0         2019-01-23  Standard Processing
# 2         2019-01-23  Standard Processing
# 4         2019-03-13              Express
# 6         2019-03-13              Express
# 8         2019-06-26  Standard Processing

# %%
# drop ship mode y -- not needed anymore
ultramerge.drop(columns='Ship Mode_y', inplace=True)

# %%
ultramerge.head()
# Out:
#          Order ID Order Date_x          Ship Mode_x Customer ID  \
# 0  CA-2019-121755   2019-01-16  standard_processing    EH-13945
# 2  CA-2019-121755   2019-01-16  standard_processing    EH-13945
# 4  CA-2019-118255   2019-03-11   express_processing    ON-18715
# 6  CA-2019-118255   2019-03-11   express_processing    ON-18715
# 8  CA-2019-169194   2019-06-20  standard_processing    LH-16900
#
#   Customer Name_x Origin Channel Country/Region         City       State  \
# 0   Eric Hoffmann          Email  United States  Los Angeles  California
# 2   Eric Hoffmann          Email  United States  Los Angeles  California
# 4   Odella Nelson          Sales  United States        Eagan   Minnesota
# 6   Odella Nelson          Sales  United States        Eagan   Minnesota
# 8  Lena Hernandez          Email  United States        Dover    Delaware
#
#    Postal Code   Region                 Category       Sub-Category  \
# 0      90049.0     West  Special Projects Muesil        Gluten Free
# 2      90049.0     West             Power Muesli  Super Fibre Boost
# 4      55122.0  Central  Special Projects Muesil        Gluten Free
# 6      55122.0  Central             Power Muesli  Super Fibre Boost
# 8      19901.0     East  Special Projects Muesil        Gluten Free
#
#         Product ID   Sales  Quantity  Discount   Profit Arrival Scan Date  \
# 0  TEC-AC-10003027  90.570         3       0.0  11.7741               NaT
# 2  OFF-BI-10001634  11.648         2       0.2   4.2224               NaT
# 4  TEC-AC-10000171  45.980         2       0.0  19.7714               NaT
# 6  OFF-BI-10003291  17.460         2       0.0   8.2062               NaT
# 8  TEC-AC-10002167  45.000         3       0.0   4.9500               NaT
#
#   Customer Name_y Ready to Ship Date Pickup Date Order Date_y  \
# 0             NaN                NaT         NaT   2019-01-16
# 2             NaN                NaT         NaT   2019-01-16
# 4             NaN                NaT         NaT   2019-03-11
# 6             NaN                NaT         NaT   2019-03-11
# 8             NaN                NaT         NaT   2019-06-20
#
#   On Truck Scan Date
# 0         2019-01-23
# 2         2019-01-23
# 4         2019-03-13
# 6         2019-03-13
# 8         2019-06-26

# %%
#check for invalid datatypes
ultramerge['Order Date_x'].head()
# Out:
# 0   2019-01-16
# 2   2019-01-16
# 4   2019-03-11
# 6   2019-03-11
# 8   2019-06-20
# Name: Order Date_x, dtype: datetime64[ns]

# %%
#lowercase
ultramerge.columns = ultramerge.columns.str.lower()

# %%
ultramerge.columns = ultramerge.columns.str.replace(" ", "_")

# %%
ultramerge.columns = ultramerge.columns.str.replace(" ", "_")

# %%
ultramerge.head()
# Out:
#          order_id order_date_x          ship_mode_x customer_id  \
# 0  CA-2019-121755   2019-01-16  standard_processing    EH-13945
# 2  CA-2019-121755   2019-01-16  standard_processing    EH-13945
# 4  CA-2019-118255   2019-03-11   express_processing    ON-18715
# 6  CA-2019-118255   2019-03-11   express_processing    ON-18715
# 8  CA-2019-169194   2019-06-20  standard_processing    LH-16900
#
#   customer_name_x origin_channel country/region         city       state  \
# 0   Eric Hoffmann          Email  United States  Los Angeles  California
# 2   Eric Hoffmann          Email  United States  Los Angeles  California
# 4   Odella Nelson          Sales  United States        Eagan   Minnesota
# 6   Odella Nelson          Sales  United States        Eagan   Minnesota
# 8  Lena Hernandez          Email  United States        Dover    Delaware
#
#    postal_code   region                 category       sub-category  \
# 0      90049.0     West  Special Projects Muesil        Gluten Free
# 2      90049.0     West             Power Muesli  Super Fibre Boost
# 4      55122.0  Central  Special Projects Muesil        Gluten Free
# 6      55122.0  Central             Power Muesli  Super Fibre Boost
# 8      19901.0     East  Special Projects Muesil        Gluten Free
#
#         product_id   sales  quantity  discount   profit arrival_scan_date  \
# 0  TEC-AC-10003027  90.570         3       0.0  11.7741               NaT
# 2  OFF-BI-10001634  11.648         2       0.2   4.2224               NaT
# 4  TEC-AC-10000171  45.980         2       0.0  19.7714               NaT
# 6  OFF-BI-10003291  17.460         2       0.0   8.2062               NaT
# 8  TEC-AC-10002167  45.000         3       0.0   4.9500               NaT
#
#   customer_name_y ready_to_ship_date pickup_date order_date_y  \
# 0             NaN                NaT         NaT   2019-01-16
# 2             NaN                NaT         NaT   2019-01-16
# 4             NaN                NaT         NaT   2019-03-11
# 6             NaN                NaT         NaT   2019-03-11
# 8             NaN                NaT         NaT   2019-06-20
#
#   on_truck_scan_date
# 0         2019-01-23
# 2         2019-01-23
# 4         2019-03-13
# 6         2019-03-13
# 8         2019-06-26

# %%
# drop order date y -- not needed anymore, dame date in order date x
ultramerge.drop(columns='order_date_y', inplace=True)

# %%
ultramerge.rename(columns={"order_date_x": "order_date"}, inplace=True)

# %%
ultramerge.rename(columns={"ship_mode_x": "processing"}, inplace=True)

# %%
# drop order date y -- not needed anymore, dame date in order date x
ultramerge.drop(columns='customer_name_y', inplace=True)

# %%
ultramerge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9995 entries, 0 to 23170
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            9995 non-null   object
#  1   order_date          9995 non-null   datetime64[ns]
#  2   processing          9995 non-null   object
#  3   customer_id         9995 non-null   object
#  4   customer_name_x     9995 non-null   object
#  5   origin_channel      9995 non-null   object
#  6   country/region      9995 non-null   object
#  7   city                9995 non-null   object
#  8   state               9995 non-null   object
#  9   postal_code         9984 non-null   float64
#  10  region              9995 non-null   object
#  11  category            9995 non-null   object
#  12  sub-category        9995 non-null   object
#  13  product_id          9995 non-null   object
#  14  sales               9995 non-null   float64
#  15  quantity            9995 non-null   int64
#  16  discount            9995 non-null   float64
#  17  profit              9995 non-null   float64
#  18  arrival_scan_date   668 non-null    datetime64[ns]
#  19  ready_to_ship_date  418 non-null    datetime64[ns]
#  20  pickup_date         418 non-null    datetime64[ns]
#  21  on_truck_scan_date  5901 non-null   datetime64[ns]
# dtypes: datetime64[ns](5), float64(4), int64(1), object(12)
# memory usage: 1.8+ MB

# %%
ultramerge.astype({'postal_code': 'int64'}).dtypes
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /Users/jannik/Desktop/DA_Bootcamp/JH-87-EDA_project_Olli_Paul_Jannik_07_22/EDA_project.ipynb Cell 45 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/jannik/Desktop/DA_Bootcamp/JH-87-EDA_project_Olli_Paul_Jannik_07_22/EDA_project.ipynb#ch0000052?line=0'>1</a> ultramerge.astype({'postal_code': 'int64'}).dtypes
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/core/generic.py:5898, in NDFrame.astype(self, dtype, copy, errors)
#    5896             res_col = col.copy() if copy else col
#    5897         else:
# -> 5898             res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    5899         results.append(res_col)
#    5901 elif is_extension_array_dtype(dtype) and self.ndim > 1:
#    5902     # GH 18099/22869: columnwise conversion to extension dtype
#    5903     # GH 24704: use iloc to handle duplicate column names
#    5904     # TODO(EA2D): special case not needed with 2D EAs
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/core/generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/core/internals/managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
#     418 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/core/internals/managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/core/internals/blocks.py:580, in Block.astype(self, dtype, copy, errors)
#     562 """
#     563 Coerce to the new dtype.
#     564
#    (...)
#     576 Block
#     577 """
#     578 values = self.values
# --> 580 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     582 new_values = maybe_coerce_values(new_values)
#     583 newb = self.make_block(new_values)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1292, in astype_array_safe(values, dtype, copy, errors)
#    1289     dtype = dtype.numpy_dtype
#    1291 try:
# -> 1292     new_values = astype_array(values, dtype, copy=copy)
#    1293 except (ValueError, TypeError):
#    1294     # e.g. astype_nansafe can fail on object-dtype of strings
#    1295     #  trying to convert to float
#    1296     if errors == "ignore":
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1237, in astype_array(values, dtype, copy)
#    1234     values = values.astype(dtype, copy=copy)
#    1236 else:
# -> 1237     values = astype_nansafe(values, dtype, copy=copy)
#    1239 # in pandas we don't store numpy str dtypes, so convert to object
#    1240 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1148, in astype_nansafe(arr, dtype, copy, skipna)
#    1145     raise TypeError(f"cannot astype a timedelta from [{arr.dtype}] to [{dtype}]")
#    1147 elif np.issubdtype(arr.dtype, np.floating) and np.issubdtype(dtype, np.integer):
# -> 1148     return astype_float_to_int_nansafe(arr, dtype, copy)
#    1150 elif is_object_dtype(arr.dtype):
#    1151
#    1152     # work around NumPy brokenness, #1987
#    1153     if np.issubdtype(dtype.type, np.integer):
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1193, in astype_float_to_int_nansafe(values, dtype, copy)
#    1189 """
#    1190 astype with a check preventing converting NaN to an meaningless integer value.
#    1191 """
#    1192 if not np.isfinite(values).all():
# -> 1193     raise IntCastingNaNError(
#    1194         "Cannot convert non-finite values (NA or inf) to integer"
#    1195     )
#    1196 return values.astype(dtype, copy=copy)
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
#ultramerge.loc[ultramerge['postal_code'].isin(" ")]
#ultramerge.loc[ultramerge('postal_code').isnull()]

pd.isna(ultramerge['postal_code'])
# Out:
# 0        False
# 2        False
# 4        False
# 6        False
# 8        False
#          ...
# 23166    False
# 23167    False
# 23168    False
# 23169    False
# 23170    False
# Name: postal_code, Length: 9995, dtype: bool

# %%
# Drop rows that has NaN values on selected columns
ultramerge_drop=ultramerge.dropna(subset=['postal_code'], inplace=True)

# %%
ultramerge.head()
# Out:
#          order_id order_date           processing customer_id customer_name_x  \
# 0  CA-2019-121755 2019-01-16  standard_processing    EH-13945   Eric Hoffmann
# 2  CA-2019-121755 2019-01-16  standard_processing    EH-13945   Eric Hoffmann
# 4  CA-2019-118255 2019-03-11   express_processing    ON-18715   Odella Nelson
# 6  CA-2019-118255 2019-03-11   express_processing    ON-18715   Odella Nelson
# 8  CA-2019-169194 2019-06-20  standard_processing    LH-16900  Lena Hernandez
#
#   origin_channel country/region         city       state  postal_code  \
# 0          Email  United States  Los Angeles  California      90049.0
# 2          Email  United States  Los Angeles  California      90049.0
# 4          Sales  United States        Eagan   Minnesota      55122.0
# 6          Sales  United States        Eagan   Minnesota      55122.0
# 8          Email  United States        Dover    Delaware      19901.0
#
#     region                 category       sub-category       product_id  \
# 0     West  Special Projects Muesil        Gluten Free  TEC-AC-10003027
# 2     West             Power Muesli  Super Fibre Boost  OFF-BI-10001634
# 4  Central  Special Projects Muesil        Gluten Free  TEC-AC-10000171
# 6  Central             Power Muesli  Super Fibre Boost  OFF-BI-10003291
# 8     East  Special Projects Muesil        Gluten Free  TEC-AC-10002167
#
#     sales  quantity  discount   profit arrival_scan_date ready_to_ship_date  \
# 0  90.570         3       0.0  11.7741               NaT                NaT
# 2  11.648         2       0.2   4.2224               NaT                NaT
# 4  45.980         2       0.0  19.7714               NaT                NaT
# 6  17.460         2       0.0   8.2062               NaT                NaT
# 8  45.000         3       0.0   4.9500               NaT                NaT
#
#   pickup_date on_truck_scan_date
# 0         NaT         2019-01-23
# 2         NaT         2019-01-23
# 4         NaT         2019-03-13
# 6         NaT         2019-03-13
# 8         NaT         2019-06-26

# %%
with pd.ExcelWriter("data/ultamerge3.xlsx") as writer:
    ultramerge.to_excel(writer)

# %%
#new column with processing time from order date to 'shipped'
ultramerge['processing_unt_shp'] = ultramerge['on_truck_scan_date'] - ultramerge['order_date']

# %%
ultramerge['processing_unt_arrival'] = ultramerge['arrival_scan_date'] - ultramerge['order_date']

# %%
ultramerge.head()
# Out:
#          order_id order_date           processing customer_id customer_name_x  \
# 0  CA-2019-121755 2019-01-16  standard_processing    EH-13945   Eric Hoffmann
# 2  CA-2019-121755 2019-01-16  standard_processing    EH-13945   Eric Hoffmann
# 4  CA-2019-118255 2019-03-11   express_processing    ON-18715   Odella Nelson
# 6  CA-2019-118255 2019-03-11   express_processing    ON-18715   Odella Nelson
# 8  CA-2019-169194 2019-06-20  standard_processing    LH-16900  Lena Hernandez
#
#   origin_channel country/region         city       state  postal_code  \
# 0          Email  United States  Los Angeles  California      90049.0
# 2          Email  United States  Los Angeles  California      90049.0
# 4          Sales  United States        Eagan   Minnesota      55122.0
# 6          Sales  United States        Eagan   Minnesota      55122.0
# 8          Email  United States        Dover    Delaware      19901.0
#
#     region                 category       sub-category       product_id  \
# 0     West  Special Projects Muesil        Gluten Free  TEC-AC-10003027
# 2     West             Power Muesli  Super Fibre Boost  OFF-BI-10001634
# 4  Central  Special Projects Muesil        Gluten Free  TEC-AC-10000171
# 6  Central             Power Muesli  Super Fibre Boost  OFF-BI-10003291
# 8     East  Special Projects Muesil        Gluten Free  TEC-AC-10002167
#
#     sales  quantity  discount   profit arrival_scan_date ready_to_ship_date  \
# 0  90.570         3       0.0  11.7741               NaT                NaT
# 2  11.648         2       0.2   4.2224               NaT                NaT
# 4  45.980         2       0.0  19.7714               NaT                NaT
# 6  17.460         2       0.0   8.2062               NaT                NaT
# 8  45.000         3       0.0   4.9500               NaT                NaT
#
#   pickup_date on_truck_scan_date processing_unt_shp processing_unt_arrival
# 0         NaT         2019-01-23             7 days                    NaT
# 2         NaT         2019-01-23             7 days                    NaT
# 4         NaT         2019-03-13             2 days                    NaT
# 6         NaT         2019-03-13             2 days                    NaT
# 8         NaT         2019-06-26             6 days                    NaT

# %%
#didnt work ultramerge["order_date"] = pd.to_datetime(ultramerge["order_date"], format="%Y-%m-%d")

# %%
ultramerge["order_date"] = pd.to_datetime(ultramerge["order_date"].dt.date)

# %%
ultramerge["order_weekday"] = ultramerge["order_date"].dt.dayofweek

# %%
# Column which weekday 
weekday = {
    0:'Monday',
    1:'Tuesday',
    2:'Wednesday',
    3:'Thursday',
    4:'Friday',
    5:'Saturday',
    6:'Sunday'}

ultramerge["order_day"] = ultramerge["order_weekday"].map(weekday)

# %%
ultramerge.head()
# Out:
#          order_id order_date           processing customer_id customer_name_x  \
# 0  CA-2019-121755 2019-01-16  standard_processing    EH-13945   Eric Hoffmann
# 2  CA-2019-121755 2019-01-16  standard_processing    EH-13945   Eric Hoffmann
# 4  CA-2019-118255 2019-03-11   express_processing    ON-18715   Odella Nelson
# 6  CA-2019-118255 2019-03-11   express_processing    ON-18715   Odella Nelson
# 8  CA-2019-169194 2019-06-20  standard_processing    LH-16900  Lena Hernandez
#
#   origin_channel country/region         city       state  postal_code  \
# 0          Email  United States  Los Angeles  California      90049.0
# 2          Email  United States  Los Angeles  California      90049.0
# 4          Sales  United States        Eagan   Minnesota      55122.0
# 6          Sales  United States        Eagan   Minnesota      55122.0
# 8          Email  United States        Dover    Delaware      19901.0
#
#     region                 category       sub-category       product_id  \
# 0     West  Special Projects Muesil        Gluten Free  TEC-AC-10003027
# 2     West             Power Muesli  Super Fibre Boost  OFF-BI-10001634
# 4  Central  Special Projects Muesil        Gluten Free  TEC-AC-10000171
# 6  Central             Power Muesli  Super Fibre Boost  OFF-BI-10003291
# 8     East  Special Projects Muesil        Gluten Free  TEC-AC-10002167
#
#     sales  quantity  discount   profit arrival_scan_date ready_to_ship_date  \
# 0  90.570         3       0.0  11.7741               NaT                NaT
# 2  11.648         2       0.2   4.2224               NaT                NaT
# 4  45.980         2       0.0  19.7714               NaT                NaT
# 6  17.460         2       0.0   8.2062               NaT                NaT
# 8  45.000         3       0.0   4.9500               NaT                NaT
#
#   pickup_date on_truck_scan_date processing_unt_shp processing_unt_arrival  \
# 0         NaT         2019-01-23             7 days                    NaT
# 2         NaT         2019-01-23             7 days                    NaT
# 4         NaT         2019-03-13             2 days                    NaT
# 6         NaT         2019-03-13             2 days                    NaT
# 8         NaT         2019-06-26             6 days                    NaT
#
#    order_weekday     COGS order_to_pickup  order_day
# 0              2  78.7959          7 days  Wednesday
# 2              2   7.4256          7 days  Wednesday
# 4              0  26.2086          2 days     Monday
# 6              0   9.2538          2 days     Monday
# 8              3  40.0500          6 days   Thursday

# %%
#adding Cost of goods sold column 
ultramerge['COGS'] = ultramerge['sales'] - ultramerge['profit']

# %%
ultramerge['order_to_pickup'] = ultramerge['on_truck_scan_date'] - ultramerge['order_date']

# %%
ultramerge.info()

# %%
#order date + 2 tage #ready to ship approx
import datetime 
ultramerge["ready_to_ship_approx"] = ultramerge["order_date"] + datetime.timedelta(days=2)

# %%
ultramerge['idle_time_approx'] = ultramerge['on_truck_scan_date'] - ultramerge['ready_to_ship_approx']

# %%
ultramerge.head()

# %%
#ready to ship

# %%
df_process.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5899 entries, 0 to 5898
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order ID            5899 non-null   object
#  1   Order Date          5899 non-null   datetime64[ns]
#  2   On Truck Scan Date  5899 non-null   datetime64[ns]
#  3   Ship Mode           5899 non-null   object
# dtypes: datetime64[ns](2), object(2)
# memory usage: 184.5+ KB

# %%
df_intern.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order ID            290 non-null    object
#  1   Ready to Ship Date  290 non-null    datetime64[ns]
#  2   Pickup Date         290 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), object(1)
# memory usage: 6.9+ KB

# %%
#second dataframe with reduced data for arrival scan date/ready to ship date if available 

#smallmerge = pd.merge(df_orders, df_campaign,  on='Order ID', how='outer')
#smallmerge = df_intern.set_index('Order ID').join(df_process.set_index('Order ID'), how='right')
# no time to test, excel ftw

# %%
with pd.ExcelWriter("data/ultamerge4.xlsx") as writer:
    ultramerge.to_excel(writer)
